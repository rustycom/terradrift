# %% [markdown]
# # 01 — Corpus stats
#
# First-pass exploratory stats on the TerraDrift corpus.
#
# This notebook is the first reviewer-facing artifact: a quick tour of the
# data, intentionally light on prose.

# %%
import duckdb, pandas as pd
# placeholder — wire to corpus parquet in v0.2
df = pd.DataFrame({"repo": [], "commits": [], "stars": []})
df.head()
